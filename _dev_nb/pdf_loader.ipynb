# %%
from pathlib import Path

# from dotenv import load_dotenv
# import os

from src.services.cleaners import PdfDocumentCleaner
from src.services.loaders.files import PdfLoader

# %%
nc_solo_pdf = Path("_dev_nb/input_data/Norme_Commune_subset.pdf")
xplore_pdf = Path(
    "/Users/jayseregon/Documents/Telecon Design/Standards Xplore/2.1.10 Underground Fibre and Conduit Architecture for FSA.pdf"
)
xplore_pdf_2 = Path(
    "/Users/jayseregon/Documents/Telecon Design/Standards Xplore/4.1 XNS List of Preferred Plant Materials.pdf"
)
xplore_pdf_3 = Path(
    "/Users/jayseregon/Documents/Telecon Design/Standards Xplore/4.2.1-XNS_OSP_Product_Standardization_Fibre_and_Connectivity.pdf"
)

# %%
sample_pdfs = {
    "xplore_1": {"pdf": xplore_pdf},
    "xplore_2": {"pdf": xplore_pdf_2},
    "xplore_3": {"pdf": xplore_pdf_3},
}

# %%
cleaner = PdfDocumentCleaner()

# %%
# async with PdfLoader() as loader:
#     raw_docs = await loader.load_document(xplore_pdf)

# # Clean the loaded documents
# cleaner = PdfDocumentCleaner()
# cleaned_docs = await cleaner.clean_documents(documents=raw_docs)

# doc_metadata_abstract = cleaned_docs[0].metadata

# doc_metadata_abstract

# %%
# async with PdfLoader() as loader:
#     docs = await loader.load_document(file_path=xplore_pdf_2)
#     await loader.documents_to_json(
#         documents=docs, filename="_dev_nb/output_data/xplore_pdf.json"
#     )

# len(docs)

# %%
# for idx, doc in enumerate(docs):
#     print(doc.page_content)
#     print(f"\n\n===PAGE BREAK {idx} ==\n\n")

# %%
# docs[2].page_content

# %%
# raw_cleaned_data = []
# for doc in docs:
#     cleaned_doc = await cleaner.clean_document(doc)
#     raw_cleaned_data.append(cleaned_doc.page_content)
#     print(cleaned_doc.page_content)
#     print("\n\n===PAGE BREAK===\n\n")

# %%
async with PdfLoader() as loader:
    output_path = Path("_dev_nb/output_data/pdf_loader")
    for k, data in sample_pdfs.items():
        docs = await loader.load_document(file_path=data["pdf"])
        data["docs"] = docs
        await loader.documents_to_json(
            documents=data["docs"], filename=output_path / f"{k}_raw.json"
        )
        data["cleaned_docs"] = await cleaner.clean_documents(documents=docs)
        await loader.documents_to_json(
            documents=data["cleaned_docs"], filename=output_path / f"{k}_clean.json"
        )

# %%
for k, data in sample_pdfs.items():
    for doc in data["cleaned_docs"]:
        print(doc.page_content)
        print("\n\n===PAGE BREAK===\n\n")
# Out:
# Underground Fibre and Conduit Architecture for FSA
# Confidential
#
# Underground Fibre and Conduit
# Architecture for FSA
#
# Best Practice & Guideline
#
# Version 1.0
#
# Date of Issue:
# 2024/Feb/15
#
# Document Number:
#
# ### 2.1.10 Revision
#
# [Publish Date]
#
# [IMAGE: Xplore® logo featuring the word "Xplore" in a modern font alongside a stylized "X" graphic element. Xplore®]
#
#
# ===PAGE BREAK===
#
#
# Underground Fibre and Conduit
# Architecture for FSA
#
# Purpose:
# The objective of this guideline is to give a clear outline of Xplore best practices and standard on fibre drop
# conduit and drop cable design architecture in FSA design.
# The ultimate goal is to place the facilities by the most economical method, minimizing material costs to
# provide a service enabled network.
# Scope:
# The guideline covers the key aspect such as conduit design consideration, drop cable installation criteria,
# and conduit sizes for different purposes. The guideline only covers drop conduit to Single
# Family/Business Unit premise, Multi-Tenant Unit premise is not covered in this document.
# Applicability:
# This document is applicable to Outside Plant fibre engineers, designers, construction managers, and
# project mangers involved in the planning, design, and implementation of underground conduit systems
# and fibre drop cable design and installation for Xplore Fibre-To-The-Premise.
# References to existing Xplore National Standards – Fibre:
# • 3.2.1 Drop Placement Guideline
# • 3.2.4 Locatable Muletape and Tonerwire
# • 3.2.6 Fibre Underground Placement Standard
#
# [IMAGE: Concise Summary: Logo of "Xplore" featuring a sleek design with an abstract representation of the letter "X" in green tones. Extracted Text: Xplore®]
#
#
# ===PAGE BREAK===
#
#
# ## Table of Contents
#
# - **1** Definitions and Abbreviations (page 4)
# - **2** Introduction (page 4)
# - **3** Conduit (page 5)
# - **3.1** Mainway Routing (page 5)
# - **3.2** Drop Conduit Routing (page 5)
# - **4** Flowerpot (page 6)
# - **4.1** Flower Pot Installation Criteria (page 6)
# - **5** Demarcation Location (page 6)
# - **6** Drop Cable (page 7)
# - **6.1** Pre-Sale Order: (page Error! Bookmark not defined.)
# - **6.2** No Pre-Sale Order: (page Error! Bookmark not defined.)
# - **7** Document Information (page 8)
# - **7.1** Original Document Authors / Contributors (page 8)
# - **7.2** Document Approvers (page 8)
# - **7.3** Document Revision History (page 8)
#
# ## Table of Figures
#
# - Figure 1: Underground Drop Placement Standard Overview (page 5)
# - Figure 2: Mainway & Drop Conduit and Flower Pot Placement (page 6)
# - Figure 3: Conduit and Drop Cable Placement in Pre-Sale and No Pre-Sale Scenario (page 7)
#
# [IMAGE: Concise summary: Logo of "Xplore" featuring stylized letters and a dynamic design. Extracted text: Xplore®]
#
#
# ===PAGE BREAK===
#
#
# # 1 Definitions and Abbreviations
#
# FDH
# Fibre Distribution Hub
# FOSC
# Fibre Optic Splice Closure
# FP
# Flower Pot
# FSA
# Fibre Servicing Area
# MPT
# Multi-Port Terminal
# MxU
# Multi (Dwelling/Tenent) Unit
# NID
# Network Interface Device
# P/L
# Property Line
# RoE
# Right of Entry
# SxU
# Single (Family/Business) Unit
#
# # 2 Introduction
#
# This guideline outlines and defines the best practices and standards for the placement of new distribution
# conduit and fibre drop cable within Xplore Fibre Servicing Area (FSA) design, offering insights to
# engineers and technicians to optimize network performance, increase installation efficiencies and
# minimize maintenance efforts.
# The main characteristics of the underground drop cable and conduit architecture are:
# • Every Single Family/Business Unit (SxU) premise will have a drop conduit placed to property line.
# • A fibre drop cable will be placed to demarcation location, where Network Interface Device (NID) is
# placed, IF there is a Right-of-Entry (RoE) agreement signed prior to FSA build.
# • Drop conduit will end at a flower pot placed at property line (P/L) if there is no RoE agreement
# signed prior to FSA build.
# • Maximum drop conduit length between pull boxes is 100m (standard) and 200m in rural settings.
# • Round Drop cable is recommended in underground pulling application.
# • All permit applications should have placement of flowerpot on the drawing.
# **See Figure 1** for a typical drop placement for SxU premise.
#
# [IMAGE: Concise summary: Logo of "Xplore" featuring a stylized "X" in green and gray tones. Extracted text: Xplore®]
# [IMAGE: **Summary:** Diagram illustrating the new underground drop placement standard for fiber optic installation, including various components such as FDH, FOSC, MPT, NID, and associated cabling. **Text Extracted:** NEW UNDERGROUND DROP PLACEMENT STANDARD FDH 1 Distribution conduit 2 Distribution fibre from FDH 3 Splice closure inside main splice vault 4 MPT stub cable 5 MPT inside ground level service box 6 18/14mm drop conduit (Microduct) to property line 7 “Flower Pot” - Circular handhole 8 Drop cable to NID or coiled inside FP. Remove FP when drop placed to house. MPT: Multi-Port Terminal P/L: Property Line FDH: Fibre Distribution Hub FOSC: Fibre Optic Splice Closure NID: Network Interconnection Device SxU w/ RoE SxU w/o RoE]
#
#
# ===PAGE BREAK===
#
#
# **Figure 1: Underground Drop Placement Standard Overview**
#
# # 3 Conduit
#
# ## 3.1 Mainway Routing
#
# Xplore’s preferred method is to place of one (1) 50mm conduit as main way at a minimum where the
# distribution cable needs to be extended within the FSA footprint. In most cases the placement of 1-50mm
# conduit will be sufficient for placement of the cable for the FSA build, for the future growth as well as
# expansion, should it be required. A second conduit of 50mm should be placed at this time if the designer
# feels that:
# • There is a chance of substantial growth in the future.
# • The route is the major route of the distribution network.
# The current cable capacities along with future and restorative capacity requirements must be considered
# when determining the size and number of conduits required through a section.
# A conduit will be considered full once 70% of its area volume has been occupied.
# Distribution cables, Transport cables, and MPT tails should be placed inside main way conduit.
#
# ## 3.2 Drop Conduit Routing
#
# Note: Xplore will place drop conduit to all Single Family or Business Unit (SxU) property.
# Xplore’s preferred method is to place one (1) 18/14mm or 14/10mm conduit as drop conduit to property line
# (P/L) at the minimum. **See Figure 2** for details.
# The path from the property line to NID, usually on the side of the building, can be direct buried if possible.
# Drop paths from Service Box (SB), where Multiport Terminal (MPT) is located, to P/L or flower pot must
# remain within the public Right-of-Way or documented utility easement and must never transition from
# private property to private property.
# It is recommended to keep both side of the conduits capped until drop cable placement is completed.
# In the public right-of-way the drop conduit length should be kept to a maximum of 100m from the
# terminal location to P/L or flower pot, to keep the pulling length to a reasonable distance.
# In some instances, such as in rural settings, there may be the need to design a longer duct length due to
# location of the terminal in relation to the P/L or flower pot. We would recommend to keep this distance at
# a maximum of 200m. Should you require longer distances we recommend a pull box in between to allow
# for easier installation at time-of-service order.
# Note: Some jurisdictions may have certain parameters in place which can impact the design and build
# such as:
# • Use of existing vs. new infrastructure.
# • Above grade vs. below grade - jurisdiction preference with factors such as snow removal and
# water table nuances. A pedestal should be used instead of Service Box.
#
# [IMAGE: Xplore logo featuring a stylized "X" design with a modern, sleek aesthetic in green and white. Xplore®]
#
#
# ===PAGE BREAK===
#
#
# # 4 Flower Pot
#
# The flower pot (FP) needs to be installed with the lid flush to ground level. This will allow for easy access
# to the drop for future installation to the building. Whether it is temporary or permanent in nature, try to
# install the flower pot in the least intrusive location for the occupants. The flower pot has an Electric Marker
# (EM) equipped locatable lid.
# When proposing flower pot placement, the location must be as close as possible to the back of Right-of-
# Way & property line, adjacent to the other utilities. Where possible it should be placed on a joint property
# line in order to feed both premises from the same flower pot.
# In areas where the location of the flower pot at property line is not feasible on the demarcation side due to
# concrete coverage or other obstructions, it can be placed in the most strategic location which will allow a
# successful drop to be placed in the future.
#
# ## 4.1 Flower Pot Installation Criteria
#
# • Only install flower pot for a SxU premise if a Right-of-Entry (RoE) is not signed during the time of
# FSA construction. In this scenario, the drop conduit ends in a flower pot is required.
# Figure 2 shows the proper design and placement of main way conduit, drop conduit, and flower pot.
#
# **Figure 2: Mainway & Drop Conduit and Flower Pot Placement**
#
# # 5 Demarcation Location
#
# Xplore’s demarcation location should be in the vicinity of the existing electrical meter and Telco / CATV
# Network Interface Device (NID).
#
# [IMAGE: Xplore logo featuring a stylized letter "X" with a dark green color scheme. Xplore®]
# [IMAGE: **Summary:** Diagram illustrating the configuration of Mainway and Drop Conduit systems, including details on Service Box and Flower Pot placement with indications for RoE. **Text Extraction:** Mainway & Drop Conduit NO RoE NO RoE ROE Drop Conduit (18/14mm) Flower Pot L/L P/L Service Box Mainway Conduit (50mm) Flower Pot is placed on the demarcation side NO RoE]
#
#
# ===PAGE BREAK===
#
#
# # 6 Drop Cable
#
# Xplore has approved two types of fibre drop cables:
# • Pre-Connectorized 1F Round Drop cable (Round drop) for Underground application.
# • Pre-Connectorized 1F Flat Drop cable (Flat drop) for Aerial application.
# All drops will run from strategically placed MPT location to feed every SxU premise in the FSA.
# The drop conduit must be placed with a tracer wire up to the property line.
# All underground designs will require 18/14mm or 14/10mm to be used for drop conduit.
# Note: Xplore is only authorized to extend fibre facility to a SxU demarcation (from property to NID) if there
# is a RoE agreement signed.
# **See Figure 3** for reference.
#
# **Figure 3: Conduit and Drop Cable Placement in Pre-Sale and No Pre-Sale Scenario**
#
# [IMAGE: Concise summary: Logo of "Xplore" featuring stylized letter "X" in dark green and light green. Extracted text: Xplore®]
# [IMAGE: **Summary:** Diagram illustrating conduit and drop cable placement in both RoE (Right of Entry) and non-RoE scenarios, highlighting distribution cables, splice closures, service boxes, and NID boxes. **Extracted Text:** Conduit & Drop Cable Placement in RoE and no-RoE Scenario RoE NO RoE 1 Distribution cable from FDH 2 Splice closure inside main splice vault 3 MPT inside ground level service box 4 Drop conduit (18/14 mm) to Property Line 5 Flower Pot 6 NID Box - Fibre termination Direct Buried Drop Cable Direct Buried Drop Cable Drop Cable in conduit Drop Cable in conduit Mainway conduit (50mm) MPT Stub TO FDH]
#
#
# ===PAGE BREAK===
#
#
# # 7 Document Information
#
# ## 7.1 Original Document Authors / Contributors
#
# Name
# Position
# Role
# Kathrin Krautzig
# Fibre Standard and Quality Consultant
# Originator / Author
# Jacky Wong
# Senior Engineer
# Originator / Author
#
# ## 7.2 Document Approvers
#
# Name
# Position
# Date
# Status
# Seth Amankwah
# Director, Fibre Engineering
# 2022/Oct/31
#
# ## 7.3 Document Revision History
#
# Date of Revision
# Revised By
# Description
# Revision
# Page #
# Revised
# Section
# -
#
# [IMAGE: Xplore logo featuring a stylized "X" design in shades of green. Xplore®]
#
# TABLE:
# |Name|Position|Role|
# |---|---|---|
# |Kathrin Krautzig|Fibre Standard and Quality Consultant|Originator / Author|
# |Jacky Wong|Senior Engineer|Originator / Author|
# ||||
#
# TABLE:
# |Name|Position|Date|Status|
# |---|---|---|---|
# |Seth Amankwah|Director, Fibre Engineering|2022/Oct/31||
#
# TABLE:
# |Date of Revision|Revised By|Description|Col4|Revision|Col6|Col7|Revised|Col9|
# |---|---|---|---|---|---|---|---|---|
# |||||Page #|||Section||
# |-|||||||||
# ||||||||||
#
# ||||||||||
#
#
# ===PAGE BREAK===
#
#
# Xplore Fibre Network – List of
# Preferred Plant Materials
# Best Practice & Guideline
#
# Version 1.2
#
# Original Date of Issue: 2022/Jan/18
#
# Document Number:
#
# ## 4.1 Latest Revision:
#
#  2024/Feb/14
#
# [IMAGE: Summary: Logo of Xplore featuring the word "Xplore" and a stylized "X". Text: Xplore®]
# [IMAGE: Xplore logo featuring a stylized 'X' design alongside the word "Xplore" with a registered trademark symbol. Xplore®]
# [IMAGE: Image Summary: A minimalistic abstract design featuring a gradient of dark green to light green backgrounds, with a smooth transition from one tone to another. Text Extraction:]
#
#
# ===PAGE BREAK===
#
#
# Xplore Fibre Network – List of
# Preferred Plant Materials
#
# Objective:
# The objective of this guideline is to provide the list preferred and approved product for Xplore fibre
# network build
#
# Relationship to existing Xplore Wireline National Standards:
# 1. N/A
#
# [IMAGE: Xplore logo featuring the brand name "Xplore" with a stylized letter "X". Xplore®]
#
#
# ===PAGE BREAK===
#
#
# ## Table of Contents
#
# - **1** List of Preferred Plant Materials (page 4)
# - **1.1** Fibre Distribution Hubs (FDH): (page 4)
# - **1.2** Inside Fibre Distribution Hub (iFDH) (page 4)
# - **1.3** Multi-Port Terminals (MPT) (page 4)
# - **1.4** In-Line Terminal with Splice Tray (page 4)
# - **1.5** Splitters (page 4)
# - **1.5.1** Installed in FOSC (1:2 and 1:16,1:4 and 1:8, and 1:32) (page 4)
# - **1.5.2** Splitters for FDH (1:32 Splitter) (page 4)
# - **1.6** Fiber Optic Splice Closures (FOSC) (page 4)
# - **1.7** Hand Holes (Service Box/Vault/Grade Level Box-GLB) (page 5)
# - **1.8** Pedestals (If the pedestal is value mounted, then an accessory is required) (page 5)
# - **1.9** Flower Pots (page 5)
# - **1.10** Conduit: Duraline, Emtelle or IPEX (page 5)
# - **1.11** Drops (page 7)
# - **1.12** Mechanical Connectors for Fibre Drops (In Field Installed) (page 7)
# - **1.13** Transition Cabinets and POI Cabinets (page 7)
# - **1.14** Fibre Patch Panel (page 7)
# - **1.15** Network Interface Device (NID) (page 8)
# - **2** Document Information (page 9)
# - **2.1** Original Document Authors / Contributors (page 9)
# - **2.2** Document Approvers (page 9)
# - **2.3** Document Revision History (page 9)
#
# [IMAGE: Xplore logo featuring the name "Xplore" and a stylized "X" design. Xplore®]
#
#
# ===PAGE BREAK===
#
#
# # 1 List of Preferred Plant Materials
#
# You can also follow the link to the Preferred Plant Material and Specification sheets Plant Material
# Note: Any alternates to this list shall be reviewed and approved by Xplore prior to incorporation into
# project
#
# ## 1.1 Fibre Distribution Hubs (FDH):
#
# 144f, 288f, 432f – Both Pole and Pad mount including splitters. Example: 144 (5 x 1:32 splitters), 288 (9 x
# 1:32 splitters), 432 (14 x 1:32 splitters)
# 1. Channell
# 2. CommScope FDH 3000
# 3. Corning LS Series
# 4. Priority FDH
# For a Pad mount FDH use the Channell FDH Vault and the Priority Vault for the respective FDHs
#
# ## 1.2 Inside Fibre Distribution Hub (iFDH)
#
# 1. Channell OIWT (Optimus Indoor Wall Terminal) 48 Fibre Count
# 2. Channell OIWT 72 Fibre Count Note: Channell 1:32 Splitters can be mounted inside these
# terminals in the fibre splice compartment
#
# ## 1.3 Multi-Port Terminals (MPT)
#
# MPT with stub cables:4, 6, 8, 12 ports – all with Opti-Tap Ports
# 1. Commscope HST (replacing MST which is phasing out)
# 2. Corning Evolv Pushlok Multi Port Terminal
#
# ## 1.4 In-Line Terminal with Splice Tray
#
# 1. Corning – SCA_9T with Opti-Tap Ports (max 12 ports – 6 on each end)
# 2. Channell Yellow Jacket
#
# ## 1.5 Splitters
#
# ### 1.5.1 Installed in FOSC (1:2 and 1:16,1:4 and 1:8, and 1:32)
#
# 1. Fiber Source
# 2. Prysmian
#
# ### 1.5.2 Splitters for FDH (1:32 Splitter)
#
# 1. Fiber X for Channell
# 2. Priority Electronics Ltd HD Splitter Module
#
# ## 1.6 Fiber Optic Splice Closures (FOSC)
#
# 1. Commscope Closures:
#
# [IMAGE: Xplore logo featuring a stylized 'X' and the word 'Xplore' in a modern font. Xplore®]
#
#
# ===PAGE BREAK===
#
#
# a. 450 series – BS, C, and D
#
# b. 400 series – for Manholes and where re-entry into existing cabled ports is not required
# 2. Corning FDC with ECAM
# 3. Channell:
# c. Green Hornet G4 - 4”x11” - 24 fibre splice tray and 8 ports for drops or flat MPT Tails.
# Can be equipped with Bulk Heads
# d. Green Hornet G5 – 5”x14”
# 4. PLP:
# ** Please note that the below PLP products are only recommended for specific projects in order to deplete the
# existing stock. These closures are not flagged for re-order **
# e. Small 6.5” x 17”
# f.
# Medium 9.5” x 19”
# g. Large 9.5” x 28”
# h. Coyote One Dome Closure for smaller applications
#
# ## 1.7 Hand Holes (Service Box/Vault/Grade Level Box-GLB)
#
# (13” x 24” x 18” D, 17” x 30” x 24” D, 24” x 36” x 24” D, 30” x 48” x 24” D, no bottoms)
# 1. Channell Bulk HH
# a. Channel XCI Logo Disk
# 2. Duralite (Oldcastle) HH
#
# ## 1.8 Pedestals (If the pedestal is value mounted, then an accessory is required)
#
# 1. Channell MAH1420
# 2. Channell MAH1212
#
# ## 1.9 Flower Pots
#
# 1. Channell GLB (9”x12” no bottom)
# 2. Duralite (10” x 10” no bottom)
#
# ## 1.10 Conduit: Duraline, Emtelle or IPEX
#
# 1. HDPE Single 18/14mm, 4-way 18/14mm, 7-way 18/14mm
# 2. HDPE SDR 11
# a. 32mm
# b. 50mm
# c. 100mm
# 3. HDPE SDR 13.5
#
# [IMAGE: Concise summary: Logo of "Xplore", featuring a stylized "X" in green and black colors. Extracted text: Xplore®]
#
#
# ===PAGE BREAK===
#
#
# a. 20mm
# b. 32mm
# c. 50mm
# d. 100mm
# 4. Conduit Caps (Channell):
# a. 19mm for 20mm HDPE
# b. 31.75mm for 32mm HDPE
# c. 50.8mm for 50mm HDPE
# 5. HDPE 90* Bends (24” and 36” radius)
# a. 32mm
# b. 50mm
# 6. HDPE Multi Duct 18/14mm
# a. 1-way 18/14mm
# b. 4-way 18/14mm
# c. 7-way 18/14mm
# 7. Multi Duct 14/10mm (Duraline or Emtelle) used for Micro Cables and Drops
# a. 1-way 14/10mm
# b. 7-way 14/10mm
# 8. Caps and Couplers (Duraline)
# a. Caps 14/10mm
# b. Straight couplers 14/10mm
# c. Caps 18/14mm
# d. Straight coupler 18/14mm
# Note: Duraline also has Transition couplers (Various sizes – ex: 12.7mm to 10mm, etc.)
# Fibre Cables
# 1. OFS – current XCI Standard
# a. Double Jacket Dielectric
# b. Single Jacket Dielectric
# c. Single Armour, Single Jacket
# d. AccuRoll Dry Core Rollable Ribbon
# 2. Superior Essex
# a. Single Armour, Single Jacket
# 3. Teldor
# a. Single Jacket Dielectric (F6 Network)
# 4. Prysmian
# a. Indoor/Outdoor LSZH, Single Jacket, Dielectric (Confederation Bridge)
# 5. Emtelle
#
# [IMAGE: Xplore logo featuring stylized "X" and brand name "Xplore®". Xplore®]
#
#
# ===PAGE BREAK===
#
#
# a. Micro Fibre Cable
# 6. AFL
# a. SpiderWeb Ribbon (SWR)
# b. LE Series / LN Series (Rodent Resistant)
# 7. CommScope
# a. D-LN Series
# 8. Corning
# a. SMF-28e+
#
# ## 1.11 Drops
#
# 1 fibre Flat Dielectric – Various lengths – OptiTap connector on one end only
# 1. Corning
# 2. Corning Roc Drop for the Evolv MPT
# a. Evolv Pushlok to Opti-tap adapter is required to connect Opti-tap port
# 3. Commscope
# 4. Fiber Source
# Round Drop Cable for underground placement only
# 1. Corning
# 2. Commscope
#
# ## 1.12 Mechanical Connectors for Fibre Drops (In Field Installed)
#
# 1. AFL Field Installed Connector
# 2. Corning Opti-Snap Single Mode Field –Installable Connector
# 3. Corning SC-APC NPC+ Connector
#
# ## 1.13 Transition Cabinets and POI Cabinets
#
# 1. Multilink Enclosure - Outside
# 2. Multilink POI Enclosure – Outside
# 3. Multilink FEC 288 Transition Cabinet – Inside
# 4. Wirewerks 1RU chassis with Optical Splicing trays for up to 24 Fibres
#
# ## 1.14 Fibre Patch Panel
#
# 1. Wirewerks (144 Fibre panel - 1R mounting space)
# a. 12F Cassettes need to be order separately
# 2. FiberSource
# a. 12 Fibre Wall Mount, 6752 Splice/Patch, 1x12F SCA w/3m 6 0 SM pigtails
# b. 24F Wall Mount, 6752, Splice/Patch, 2x12F SCA w/3m 2 0 SM pigtails
#
# [IMAGE: Xplore logo featuring a stylized 'X' with green and gray tones. Xplore®]
#
#
# ===PAGE BREAK===
#
#
# 3. Multilink 288F – 6.5R mounting space (use in F6 CO’s)
# a. 12F Cassettes need to be order separately
#
# ## 1.15 Network Interface Device (NID)
#
# 1. Primex P350FSC-THG2SA 2 Fiber Enclosure (Wireline – SC/APC Connectors)
# 2. Primex P750FSC-THG6SA 6 Fibre Enclosure (Wireline – SC/APC Connectors)
# 3. Primex P1000MFSC-THG12SA-SD 12 Fibre Enclosure (Wireline – SC/APC Connectors)
# 4. Primex P1000MFSC-THG12LU-SD 12 Fiber Enclosure (Wireless – LC/UPC Connectors)
# 5. Primex P1000MFSC-THG24LU-SD 24 Fiber Enclosure (Wireless – LC/UPC Connectors)
# Note: Most of these products are referenced in the Xplore National Standards – Fibre documents. Please
# contact Xplore project Manager for latest revised copy.
#
# [IMAGE: Xplore logo featuring a stylized "X" with a modern design and the brand name "Xplore" in a refined font. Xplore®]
#
#
# ===PAGE BREAK===
#
#
# # 2 Document Information
#
# ## 2.1 Original Document Authors / Contributors
#
# Name
# Position
# Role
# Jacky Wong
# Senior Engineer
# Originator / Author
#
# ## 2.2 Document Approvers
#
# Name
# Position
# Date
# Signature
# Seth Amankwah
#
# Director, Fibre
# Engineering
# 2022/Jan/18
#
# ## 2.3 Document Revision History
#
# Date of Revision
# Revised By
# Description
# Revision
# Page #
# Revised
# Section
# 2023/Mar/06
#
# Jacky Wong
#
# Reformat document to match
# Xplore brand
# All Page
# All Section
#
# 2023/11/15
# Jacky Wong
#
# Added HST to approved MPT
# Added Pushlok to Opti-tap adapter
#
# 1.3 & 1.12
#
# 2023/12/14
#
# Kathrin Krautzig
#
# Added Corning FDH LS Series
# Added Corning FOSC with ECAM
# and added note on phasing out
# Coyote closure
# 4, 5
# 1.1 and 1.6
#
# 2024/01/12
# Kathrin Krautzig
#
# Added cables
#
# # 8 Fibre
#
# Cables
#
# 2024/02/14
# Kathrin Krautzig
# Added 4 port terminal
# Added Round drop cable for
# underground placement
# 4
#
# # 7 Terminal
#
# Drop Cable
#
# [IMAGE: Xplore logo featuring stylized letter "X" in green and black colors. Xplore®]
#
# TABLE:
# |Name|Position|Role|
# |---|---|---|
# |Jacky Wong|Senior Engineer|Originator / Author|
# ||||
#
# TABLE:
# |Name|Position|Date|Signature|
# |---|---|---|---|
# |Seth Amankwah|Director, Fibre Engineering|2022/Jan/18||
#
# TABLE:
# |Date of Revision|Revised By|Description|Col4|Revision|Col6|Col7|Revised|Col9|
# |---|---|---|---|---|---|---|---|---|
# |||||Page #|||Section||
# |2023/Mar/06|Jacky Wong|Reformat document to match Xplore brand|All Page|||All Section|||
# |2023/11/15|Jacky Wong|Added HST to approved MPT Added Pushlok to Opti-tap adapter||||1.3 &amp; 1.12|||
# |2023/12/14|Kathrin Krautzig|Added Corning FDH LS Series Added Corning FOSC with ECAM and added note on phasing out Coyote closure|4, 5|||1.1 and 1.6|||
# |2024/01/12|Kathrin Krautzig|Added cables|8|||Fibre Cables|||
#
# |2024/02/14|Kathrin Krautzig|Added 4 port terminal Added Round drop cable for underground placement|4 7|||Terminal Drop Cable|||
#
#
# ===PAGE BREAK===
#
#
# OSP Product Standardization – Fibre
# & Connectivity
# General Document
#
# Version 2.1
#
# Original Date of Issue: 2022/Oct/24
#
# Document Number:
#
# ### 4.2.1 Latest Revision:
#
#  2024/Jan/02
#
# [IMAGE: Xplore logo featuring a stylized "X" with the word "Xplore" beside it. Xplore® X]
# [IMAGE: Xplore logo with a modern design emphasizing the brand name. Xplore®]
#
#
# ===PAGE BREAK===
#
#
# OSP Product Standardization – Fibre &
# Connectivity
#
# Objective:
# Objective: To Evaluate and standardize Xplore Outside Plant (OSP) Fibre network equipment. Establish
# Xplore Fibre OSP preferences and requirement. Determine “Standard” and “Acceptable Alternate” choice
# in each category for Xplore Fibre deployment across the nation.
# Not within the scope: Individual product performance evaluation as these products are already trialed,
# tested, and widely deployed by other service providers in Canada and other parts of the world. Instead
# focused on how individual products integrate and perform to Xplore fibre network and overall operations
# and maintenance
#
# Relationship to existing Xplore Wireline National Standards:
# 1. NONE
#
# [IMAGE: Xplore® X logo. Xplore® X]
#
#
# ===PAGE BREAK===
#
#
# ## Table of Contents
#
# - 1. Evaluation Metrics ................................................................................................................................. 5
# - 2. Evaluation Ratings ................................................................................................................................ 5
# - 3. OSP Product Evaluation and Rating ..................................................................................................... 5
#
# Multi-Port Terminal (MPT) ............................................................................................................. 6
# 3.1.1.
# Corning Evolv ™ Terminal with Pushlok™ Technology ........................................................ 6
# 3.1.2.
# Corning Optisheath® MultiPort Terminal .............................................................................. 7
# 3.1.3.
# Commscope NOVUX™ Hardened Terminal (HST) .............................................................. 8
#
# Drop Cables .................................................................................................................................. 8
# 3.2.1.
# Corning Evolv ROC™ Drop Cable ........................................................................................ 9
# 3.2.2.
# Corning / Commscope OptiTap® Drop Cable ..................................................................... 10
#
# Mechanical Connectors for Drop Cable (SC) .............................................................................. 11
# 3.3.1.
# Corning NPC+ ..................................................................................................................... 11
# 3.3.2.
# Commscope QWIK-II .......................................................................................................... 12
# 3.3.3.
# AFL FASTConnect SC ........................................................................................................ 12
#
# Fibre Optic Splice Closure (FOSC) ............................................................................................. 13
# 3.4.1.
# Commscope FOSC-450’s ................................................................................................... 13
# 3.4.2.
# Corning Fibre Dome Closure with ECAM Port .................................................................... 14
# 3.4.3.
# Channell – Green Hornet Series ......................................................................................... 16
# 3.4.4.
# PLP – Coyote® Dome Closure ........................................................................................... 17
#
# Inline Terminal ............................................................................................................................. 18
# 3.5.1.
# Corning OptiSheath SCA-9T Aerial Inline Terminal ............................................................ 18
# 3.5.2.
# Corning OptiSheath SCA-9T Aerial Inline Terminal ............................................................ 19
#
# Fibre patch Panel (WIC) .............................................................................................................. 19
# 3.6.1.
# Wirewerks’ NextSTEP™1U Rack Mount Patch Panel ........................................................ 19
#
# Inside Fibre Transition Cabinet ................................................................................................... 20
# 3.7.1.
# Multilink FEW-288 Inside Fibre Transition Cabinet ............................................................. 20
#
# Fibre Distribution Hub (FDH) – Outdoor ..................................................................................... 21
# 3.8.1.
# Channell Optimus Cabinet Fibre Hub (OCFH) .................................................................... 21
# 3.8.2.
# Corning LS Series FDH (288F) ........................................................................................... 22
# 3.8.3.
# Commscope Outdoor FDH 3000 ......................................................................................... 23
#
# Outside Plant Fibre Optic Cable .................................................................................................. 24
# 4.
# OSP Products Standardization Summary ........................................................................................... 25
# 5.
# Document Information ......................................................................................................................... 26
#
# Original Document Authors / Contributors .................................................................................. 26
#
# Document Approvers .................................................................................................................. 26
#
# Document Revision History ......................................................................................................... 26
#
# [IMAGE: Xplore® X logo design in teal color. Xplore® X]
# [IMAGE: Summary: An illustration of a bat silhouette. Text extraction: No text found in the image.]
# [IMAGE: **Summary:** A simple black silhouette of a cat in a playful pose. **Text Extraction:** N/A]
# [IMAGE: Image Summary: Icon of a snail, representing slow movement or nature. Text Extraction: [No text present in the image\\]]
# [IMAGE: **Summary:** An abstract black and white icon of a single outlined feather. **Text Extraction:** None]
# [IMAGE: Concise summary: A black silhouette of a cat with a long tail, depicted in a minimalist design. Text extracted: None]
# [IMAGE: **Summary:** Image of a simple black and white icon representing a house with a slanted roof. **Text Extraction:** No text available in the image.]
# [IMAGE: **Summary:** An illustration of a simple, stylized octopus with eight tentacles. **Text Extraction:** No text found.]
# [IMAGE: **Summary:** Illustration of a simplified eye with labeled parts including iris, pupil, sclera, and cornea. **Text Extraction:** Iris Pupil Sclera Cornea]
# [IMAGE: **Summary:** Icon of a home with an arrow pointing upwards, indicating upward navigation or access to a home page. **Text extracted:**]
# [IMAGE: **Image Summary:** A black silhouette of a person reaching out, integrated into the letter "R" of "RESOURCES." The design suggests support or assistance. **Text Extraction:** RESOURCES REACHING OUT]
# [IMAGE: **Summary:** Icon of an open book, symbolizing reading or education. **Extracted Text:** (No text present in the image.)]
# [IMAGE: **Image Summary:** Icon of a bowling pin, simplified and stylized, pointing upward. **Extracted Text:** N/A]
#
#
# ===PAGE BREAK===
#
#
# ## Table of Figures
#
# - Figure 1: Corning Evolv Terminal (page 6)
# - Figure 2: Coning Evolv Terminal with Pushlok connector (page 6)
# - Figure 3: Corning OptiSheath MPT (page 7)
# - Figure 4: Commscope HST MPT (page 8)
# - Figure 5: Corning Evolv ROC drop with Pushlok connector (page 9)
# - Figure 6: OptiTap adapter (Left), Pushlok connector (Right) (page 9)
# - Figure 7: Corning Evolv ROC drop with OptiTap adapter on (page 9)
# - Figure 8: OptiTap adapter on ROC drop cable (page 9)
# - Figure 9: Commscope FHD Drop Cable Series (page 10)
# - Figure 10: FHD Drop Cable connector (page 10)
# - Figure 11: Pushlok to OptiTap jumper cable (page 10)
# - Figure 12: Corning NPC+ SC Connector (page 11)
# - Figure 13: Commscope QWIK-II SC Connector (page 12)
# - Figure 14: AFL FASTConnect SC Connector (page 13)
# - Figure 15: Commscope FOSC 450-C (page 14)
# - Figure 16: Corning Fibre Dome Closure with ECAM system (page 15)
# - Figure 17: The External Cable Assembly Module (ECAM) system on Corning FOSC (page 15)
# - Figure 18: Channell Green Hornet Enclsore (G5N is shown) (page 16)
# - Figure 19: PLP Coyote Dome Closure (page 17)
# - Figure 20: Corning OptiSheath SCA-9T Aerial Inline Terminal (24") (page 18)
# - Figure 21: Channell Yellow Jacket Aerial Inline Terminal (page 19)
# - Figure 22: Multilink FEW Cabinet (page 20)
# - Figure 23: Channell Optimus Cabinet Fibre Hub (Pole Mounted Model showns) (page 21)
# - Figure 24: Corning FDH LS Series (page 22)
# - Figure 25: Commscope FDH 3000 (page 23)
# - Figure 26: Commscope FDH 3000 By-Pass access (page 23)
#
# [IMAGE: Concise Summary: Logo of "Xplore X" featuring a stylized "X" with a clean and modern design. Extracted Text: Xplore® X]
#
#
# ===PAGE BREAK===
#
#
# 1. Evaluation Metrics
# Evaluation will focus on connectivity, adaptability, easiness of installation, maintenance, and field
# application to other OSP components of Xplore fibre network as a whole system. Individual performance
# will also be considered but preference will be given to components that integrates best to the overall
# network.
# Individual product will be evaluated based on following metrics:
# 1. Technical Speciation
#
# – Packaging, Environment, Performance Standards
# 2. Systems Engineering
# – How the product interacts with other components
# 3. Craftsmanship
#
# – Field installation, deployment, and maintenance
# 4. Pricing
#
# – Cost per unit
# 5. Lead Time and Distribution
# – Time to order and deliver material to warehouse/site
# 6. Customer Care
#
# – Post-sale customer/client support service
# 2. Evaluation Ratings
# A letter grade rating will be assigned to each metrics listed in Section 1. A breakdown of rating is listed as
# follow:
# Letter Grade Rating
# Description
# A – Excellent
# -
# No issue to report
# -
# Exceed expectation
# -
# No further test is required
# B – Very Good
#
# -
# 1 – 2 issues to report
# -
# No further test is required
# C – Good
#
# -
# 2 – 4 issues to report
# -
# Field trial is highly recommended
# D – Fair
#
# -
# Major issue(s) to report
# -
# Further study and review is required
# -
# Field trial is mandatory before deployment
#
# Note: The rating is assigned to each metric centric to field application on Xplore fibre network. Issues
# reported do not necessary reflect issue with the product itself but instead associates with field application
# during Xplore fibre network build and operation.
# 3. OSP Product Evaluation and Rating
# Only Evaluation Metric 1-3 are rated in this document as 4-6 are beyond the scope of the evaluation at
# this moment. Rating for metric 4-6 will be assigned once more information is given in future date.
# An overall rating will be assigned at the end of each product section which indicates if the product is the
# preferred product of its category – Standard Choice, or “Number 2” choice as acceptable direct
# replacement – Acceptable Alternate Choice, or simply avoid using the product – Not Standard Choice.
# NOTE: Skip to Section 4 for OSP Product Standardization Summary
#
# [IMAGE: Xplore® X logo in stylized font, featuring a prominent 'X' design. Xplore® X]
#
# TABLE:
# |Letter Grade Rating|Description|
# |---|---|
# |A – Excellent|- No issue to report - Exceed expectation - No further test is required|
# |B – Very Good|- 1 – 2 issues to report - No further test is required|
# |C – Good|- 2 – 4 issues to report - Field trial is highly recommended|
#
# |D – Fair|&amp;#45; Major issue(s) to report &amp;#45; Further study and review is required &amp;#45; Field trial is mandatory before deployment|
#
#
# ===PAGE BREAK===
#
#
# Multi-Port Terminal (MPT)
# 3.1.1. Corning Evolv ™ Terminal with Pushlok™ Technology
# Overview:
# Pushlok ™ hardened connector technology is the key component enabling smaller terminals. The terminal
# is up to four times smaller than existing solution allowing users to place on strand, façade and avoid pole-
# attachment fees, reduce size of handle and pedestal footprint, and reuse existing infrastructure
#
# **Figure 1: Corning Evolv Terminal**
#
# **Figure 2: Coning Evolv Terminal with Pushlok connector**
#
# Metric
# Rating
# Remark
# Technical Specifications
# A
# Compact design
# System Engineering
# A
# Easy to connect with Pushlok plug
# Craftsmanship
# A
# Ease of use, user-friendly, and “dummy’ proof
#
# Pros:
# -
# Compact in size so it fits into smaller supporting infrastructures
# -
# Drop + connector is smaller compare to existing solution
# -
# Easy to install both the terminal and drop connection
# -
# Built-in Splitter is an optional add-on to provide addition option for MxU application other than single
# drop to premise usage
#
# [IMAGE: Xplore logo featuring the text "Xplore®" and the letter "X" in a stylized design. Xplore®]
# [IMAGE: **Summary**: Section 3.1, possibly from a document, focused on a specific topic, indicated by the number formatting. **Extracted Text**: 3.1.]
# [IMAGE: Image Summary: Multiple black electronic components of varying sizes arranged in line, each with multiple pins and a design indicating they may serve as connectors or circuit elements. Extracted Text: None]
# [IMAGE: **Image Summary:** Two images featuring tools related to wiring: the left shows a device with multiple ports and cables attached, while the right displays a removable tip with branding. **Extracted Text:** COIL-NIQUEL]
#
# TABLE:
# |Metric|Rating|Remark|
# |---|---|---|
# |Technical Specifications|A|Compact design|
# |System Engineering|A|Easy to connect with Pushlok plug|
#
# |Craftsmanship|A|Ease of use, user&amp;#45;friendly, and “dummy’ proof|
#
#
# ===PAGE BREAK===
#
#
# Cons:
# -
# Corning only provides flat drop during product evaluation. Fibre bending during installation could
# be an issue compare to typical round drop cable. Corning may have a solution but it is yet to be
# determined. See more on Drop Cable evaluation
# -
# Adaptor/jumper cable to convert from Commscope drop cable is available but the length could be
# an issue. Corning may have a solution but it is yet to be determined. See more on Drop Cable
# evaluation
# Overall Rating:
# Number 1 Choice: Standard Choice
#
# 3.1.2. Corning Optisheath® MultiPort Terminal
# Overview:
# The stubbed/stubless OptiSheath® MultiPort Flex Terminal is designed for use in outside plant fiber
# access networks. In particular, its reliability makes it ideal for FTTH applications. This terminal provides
# sealed environmental protection, as well as easy incremental connection of subscriber drop cables. This
# MultiPort Flex Terminal also accelerates FTTH community acceptance through its ability to fit inside some
# of the most compact pedestals and handholes on the market. It is available in several configurations with
# 4, 6, 8, and 12 OptiTap® single-fiber connector ports.
#
# **Figure 3: Corning OptiSheath MPT**
#
# Metric
# Rating
# Remark
# Technical Specifications
# A
# Industry leading MPT model
# System Engineering
# B
# Larger footprint with/out bracket
# Craftsmanship
# A
# Easy to install drop (Corning Optitap connector)
# Pros:
# -
# Widely deployed by the industry – durable, easy to maintain (add/remove service)
# -
# Pre-connectorized OptiTap ® drops to customer premises
# Cons:
# -
# Much larger dimension than Corning Evolv Terminal. Pre-connectorized drop has longer lead/tail
# than Corning Evolv Pushlok drop that requires larger footprint for underground application
# Overall Rating:
# Number 2 Choice : Acceptable Alternate Choice
#
# [IMAGE: Xplore logo featuring the word "Xplore" in a stylized font alongside a prominent "X" element. Xplore® X]
# [IMAGE: - Summary: Image features two cable assemblies designed for audio communication, including a multi-channel connector and a single-channel connector. - Text: (No text present in the image to extract.)]
#
# TABLE:
# |Metric|Rating|Remark|
# |---|---|---|
# |Technical Specifications|A|Industry leading MPT model|
# |System Engineering|B|Larger footprint with/out bracket|
#
# |Craftsmanship|A|Easy to install drop (Corning Optitap connector)|
#
#
# ===PAGE BREAK===
#
#
# 3.1.3. Commscope NOVUX™ Hardened Terminal (HST)
# Overview:
# Successor of Commscope MST which was previously approved. HST is lighter and smaller than MST.
# Similar product to Corning Optisheath MPT in size, connection type, and footprint. It utilizes the same
# OptiTap connector to drop connection.
# Commscope HST and Corning Optisheath Evolv can be use interchangeably depends on the Pricing,
# Lead time and Distribution.
#
# **Figure 4: Commscope HST MPT**
#
# Metric
# Rating
# Remark
# Technical Specifications
# A
# Industry leading MPT model
# System Engineering
# A
# Larger footprint with/out bracket
# Craftsmanship
# A
# Easy to install drop (Corning Optitap connector)
# Pros:
# -
# Widely deployed by the industry – durable, easy to maintain (add/remove service)
# -
# Pre-connectorized OptiTap ® drops to customer premises
# Cons:
# -
# Much larger dimension than Corning Evolv Terminal. Pre-connectorized drop has longer lead/tail
# than Corning Evolv Pushlok drop that requires larger footprint for underground application
# Overall Rating:
# Number 2 Choice: Acceptable Alternate Choice
#
#  Drop Cables
# Xplore Fibre Network would prefer drop cable with connectorized on multiport terminal (MPT) end only. The
# field end is mechanically connected, to be spliced to mechanical connector in the field. The reason to avoid
# pre-connectorized drop cable (field end) is to have the flexibility to have custom drop length tailored for
# each application without the need of storing slacks on MPT end or on customer’s demarcation point.
# Round drop cables are preferred for underground application for the easiness to pull cable in and out of
# underground infrastructure which usually has less room to work with the bend radius. Flat drop cables are
# preferred for aerial application due to fitness to wedge clamp on pole. For the application where there is
#
# [IMAGE: Xplore logo featuring a stylized "X" and the word "Xplore" with a registered trademark symbol. Xplore® X]
# [IMAGE: **Summary:** An illustration or design featuring the number "3.2" in a green color. **Text Extracted:** 3.2.]
# [IMAGE: **Summary:** Image of a black COMMCOPE fiber optic junction box featuring multiple connectors labeled 1 to 8, designed for cable systems. **Text Extraction:** COMMCOPE Fiber Optic Systems QR Code Model Number: [Not visible\\]]
#
# TABLE:
# |Metric|Rating|Remark|
# |---|---|---|
# |Technical Specifications|A|Industry leading MPT model|
# |System Engineering|A|Larger footprint with/out bracket|
#
# |Craftsmanship|A|Easy to install drop (Corning Optitap connector)|
#
#
# ===PAGE BREAK===
#
#
# combination of underground and aerial portion, the preference goes to whichever application, aerial or
# underground, has longer run length.
# 3.2.1. Corning Evolv ROC™ Drop Cable
# Overview:
# Corning designs and manufactures the ROC™ drop cable assembly with factory-terminated,
# environmentally sealed and hardened connectors to reduce the cost and time of drop cable deployment.
# Corning hardened connectors provide superior durability and reliability in the drop segment of the
# network. This assembly also offers significant improvements in cable management.
#
# **Figure 5: Corning Evolv ROC drop with Pushlok**
#
# connector
#
# **Figure 6: OptiTap adapter (Left), Pushlok connector**
#
# (Right)
#
# **Figure 7: Corning Evolv ROC drop with OptiTap adapter**
#
# on
#
# **Figure 8: OptiTap adapter on ROC drop cable**
#
# Metric
# Rating
# Remark
# Technical Specifications
# A
#
# System Engineering
# A
# Flexible – OptiTap connector available
# Craftsmanship
# A
#
# Pros:
# -
# OptiTap adaptor available to plug into Optisheath MPT
# -
# Available with one or both ends connectorized
# -
# Hybrid (one end with an OptiTap Connector, one end with standard SC connector) available with
# or without pulling grip
# Cons:
# -
# Corning only provides flat drop during product evaluation. Fibre bending during installation could
# be an issue compare to typical round drop cable. A special wedge clamp can be purchased for
# aerial pole application to customer premises
#
# [IMAGE: Concise summary: Logo of "Xplore" with an emphasis on the letter "X". Extracted text: Xplore® X]
# [IMAGE: Concise Summary: A black flexible cable with a connector at one end, possibly used for electronic devices or instruments. Extracted Text: None]
# [IMAGE: **Image Summary:** A close-up view of a long, coiled black cable with connectors on both ends. **Extracted Text:** None]
# [IMAGE: Concise Summary: Image of two electric connectors with black and orange detailing and cables, showcasing a close-up view against a neutral background. Text Extraction: No text present in the image.]
# [IMAGE: Concise summary: Two black electrical connectors with red ring accents, appearing to be designed for cable connections. Extracted text: None]
#
# TABLE:
# |Metric|Rating|Remark|
# |---|---|---|
# |Technical Specifications|A||
# |System Engineering|A|Flexible – OptiTap connector available|
#
# |Craftsmanship|A||
#
#
# ===PAGE BREAK===
#
#
# Overall Rating:
# Number 1 Choice: Standard Choice
#
# 3.2.2. Corning / Commscope OptiTap® Drop Cable
# Overview:
# Fiber Optic Drop Cable Assembly for outside plant applications:
# -
# Backward-compatible with older generations of hardened and non-hardened connector systems,
# FHD drop cable integrates seamlessly into existing fiber-optic networks
# -
# Hardened drop cables incorporate hardened connector technology that is designed to withstand
# the rugged outside plant environment
# -
# Hardened drop cables simplify installation and maintenance by reducing splicing requirements in
# the distribution portion of the network
#
# **Figure 9: Commscope FHD Drop Cable Series**
#
# **Figure 10: FHD Drop Cable connector**
#
# **Figure 11: Pushlok to OptiTap jumper cable**
#
# Metric
# Rating
# Remark
# Technical Specifications
# A
#
# System Engineering
# B
# Needs 7’ jumper cable to connect Corning Evolv MPT
# Craftsmanship
# A
#
# Pros:
# -
# Widely deployed by the industry – durable, easy to maintain (add/remove service)
# -
# Round drop cable that is flexible for both aerial and underground application
#
# [IMAGE: Xplore logo featuring a stylized 'X' and the brand name "Xplore®". Xplore® X]
# [IMAGE: - Summary: A coiled black cable with connectors on either end, typically used for electrical or audio applications. - Text: None]
# [IMAGE: **Summary:** Two electrical connectors with protective caps, featuring a latch mechanism and wiring, designed for secure connections. **Text Extraction:** None]
# [IMAGE: Concise Summary: A black cable with connectors on each end, packaged with a label. Text Extraction: Kabel NSK-550006 M4304-01 CNC Part number: 10-2316-09 Description: 12' 10-Pin HTS 8544.49.0000 P.O. No: 107153047 Net Weight: 0.99 lbs Qty: 1 Vendor: 154109 Date: 10/19/2021 Barcode: (scannable barcode)]
#
# TABLE:
# |Metric|Rating|Remark|
# |---|---|---|
# |Technical Specifications|A||
# |System Engineering|B|Needs 7’ jumper cable to connect Corning Evolv MPT|
#
# |Craftsmanship|A||
#
#
# ===PAGE BREAK===
#
#
# Cons:
# -
# Does require a 7’ long jumper cable to connect OptiTap drop to Corning Pushlok connector
# Overall Rating:
# Number 2: Acceptable Alternate choice of drop cable
#
#  Mechanical Connectors for Drop Cable (SC)
# Fibre optic mechanical connector (type SC) is used to connect fibre drop to fibre termination point
# equipment. SC, abbreviated for Subscriber Connector, has also been referred to as Square Connector or
# Standard Connector. It’s a popular fiber-optic connector due to its low-cost, durability and simple
# installation for both point-to-point and passive optical networking.
# SC is a push-pull device that uses a ceramic ferrule to deliver highly accurate alignment in a fiber-optic
# link. It’s a square-shaped connector—also known as “stick and click” for its SC acronym—that comes with
# a locking tab that enables the push-on and pull-off operation
# 3.3.1. Corning NPC+
# Overview:
# The NPC+ (No Polish Connector) eliminates field polishing, loose parts, and termination tools. The
# innovative buffer clamp design eliminates rework by delivering superior twist and transmission with
# applied load (TWAL) mechanical performance. After fiber preparation and cleaving, installation is a simple
# three-step process: insert fiber, actuate splice, activate the buffer clamp. Faster than fusion splicing, the
# NPC+ delivers savings in installation expense and reduces overall complexity of termination
#
# **Figure 12: Corning NPC+ SC Connector**
#
# Metric
# Rating
# Remark
# Technical Specifications
# A
#
# System Engineering
# A
# Flexible – OptiTap connector available
# Craftsmanship
# A
#
# Pros:
# -
# Corning mechanical connector has longer channel that fits into connection tightly
# Cons:
# -
# None
# Overall Rating:
# Number 1: Standard choice
#
# [IMAGE: Xplore® X logo design with modern typography in green. Xplore® X]
# [IMAGE: Summary: The image features a numerical representation resembling a section or point in a document, highlighted in green. Text extraction: 3.3.]
# [IMAGE: Image Summary: Three medical syringes with green and transparent plastic components arranged in a row. The syringes feature different configurations and nozzle designs. Text Extraction: No text found in the image.]
#
# TABLE:
# |Metric|Rating|Remark|
# |---|---|---|
# |Technical Specifications|A||
# |System Engineering|A|Flexible – OptiTap connector available|
#
# |Craftsmanship|A||
#
#
# ===PAGE BREAK===
#
#
# 3.3.2. Commscope QWIK-II
# Overview:
#
# **Figure 13: Commscope QWIK-II SC Connector**
#
# ...
# Gaining entry to the Yellow Jacket terminal is quick and easy through its cover compression clamps. The
# terminal is designed to mount effortlessly on a strand (aerial mounting brackets included) and is capable
# of accommodating 4 distribution cable entry ports in either direction for maximum flexibility.
# The Yellow Jacket allows for ample slack storage and is compatible with Channell’s Universal Splice
# Trays for a maximum splice capacity up to 144F. Multiple splitter configurations can be accommodated for
# both centralized and distributed split deployments.
#
# **Figure 21: Channell Yellow Jacket Aerial Inline Terminal**
#
# Metric
# Rating
# Remark
# Technical Specifications
# C
#
# System Engineering
# C
#
# Craftsmanship
# D
#
# Summary:
# The design and build of this terminal does not fit Xplore fibre network deployment. It is not ideal for direct
# substitute of Corning OptiSheath product.
# Overall Rating:
# Not Standard Choice of Inline Terminal
#  Fibre patch Panel (WIC)
# 3.6.1. Wirewerks’ NextSTEP™1U Rack Mount Patch Panel
# Overview
# Wirewerks’ NextSTEP™ 1U Rack Mount Patch Panel features an industry-first horizontal slot design for
# mounting slide-in NextSTEP Fiber Modules and cassettes. Each horizontal slot is ‘stepped’ (offset) from
#
# [IMAGE: Xplore® X logo design featuring stylized letters and a modern aesthetic. Xplore® X]
# [IMAGE: **Summary:** Numeric display of "3.6" in a stylized font. **Text Extracted:** 3.6]
# [IMAGE: **Image Summary:** A black cable management box with a metal handle, featuring a logo labeled "CHANNEL." **Extracted Text:** CHANNEL]
#
# TABLE:
# |Metric|Rating|Remark|
# |---|---|---|
# |Technical Specifications|C||
# |System Engineering|C||
#
# |Craftsmanship|D||
#
#
# ===PAGE BREAK===
#
#
# adjacent slots, providing easy physical and visual access to any individual fiber module without disrupting
# other modules or fibers co-resident in the same panel.
# NextSTEP 1U Patch Panels feature unrestricted front and rear access for easy installation and
# maintenance. The guide-rail system that secures each slide-in/out module into place features ‘click in-
# place’ stops that indicate when a module is properly seated in its correct operational position as well as
# partially withdrawn positions for easy technician access.
# NextSTEP 1U Patch Panels are compatible with all NextSTEP Fiber Modules, and accept up to twelve
# (12) single-slot modules in any combination in any slot position. NextSTEP Modules slide in or out from
# the front or rear of the panel without tools -- making installations, MACs, and maintenance fast, easy and
# cost-effective.
# Fiber counts in 1RU for typical configurations include up to 144F with LC/SC-Patch or Distribution
# Modules; up to 288F with Splice Tray Modules; and up to 1,152F with MPO Adapter Strip Modules.
# Metric
# Rating
# Remark
# Technical Specifications
# A
#
# System Engineering
# A
# 1RU, Easy slide in/out. 10m or 30m tail available
# Craftsmanship
# A
#
# Summary:
# The NextSTEP 1U Patch Panel’s modular design and building block configuration mean that each version
# may be quickly and easily field-upgraded - extending operational lifespan, reducing spares inventories,
# and increasing ROI.
# Overall Rating:
# Number 1: Standard Choice
#
#  Inside Fibre Transition Cabinet
# 3.7.1. Multilink FEW-288 Inside Fibre Transition Cabinet
# Overview
# The Mulitlink FEW-288 inside, wall mounted Fibre Transition Cabinet can accommodate the splicing of
# 288 OSP Fibre to ISP Fibre stub cable to a Fibre Patch Panel. Splice Trays are to be ordered separately.
#
# **Figure 22: Multilink FEW Cabinet**
#
# [IMAGE: Xplore logo featuring stylized "X" and the word "Xplore" with a registered trademark symbol. Xplore® X]
# [IMAGE: Summary: A numerical value displayed prominently, likely indicating a measurement or rating. Text extracted: 3.7.]
# [IMAGE: - Summary: Open black electronic equipment enclosure with internal mounting features and ventilation slots. - Text: None]
#
# TABLE:
# |Metric|Rating|Remark|
# |---|---|---|
# |Technical Specifications|A||
# |System Engineering|A|1RU, Easy slide in/out. 10m or 30m tail available|
#
# |Craftsmanship|A||
#
#
# ===PAGE BREAK===
#
#
# Metric
# Rating
# Remark
# Technical Specifications
# A
#
# System Engineering
# A
#
# Craftsmanship
# A
#
# Summary:
# Xplore has been deploying this transition cabinet in the field in multiple location. It is the smallest
# dimension of similar product available in the market.
# Overall Rating:
# A – Standard Choice of Inside Fibre Transition Cabinet
#
#  Fibre Distribution Hub (FDH) – Outdoor
#
# 3.8.1. Channell Optimus Cabinet Fibre Hub (OCFH)
# Overview
# The Vault/Pad mounted Optimus Cabinet Fiber Hub is a powder coated aluminum cabinet designed for
# centralized split points in a PON network. The 72, 96, 144, and 288 ﬁber termination choices allow
# operators to scale the cabinet cost to their network design.
#
# **Figure 23: Channell Optimus Cabinet Fibre Hub (Pole Mounted Model showns)**
#
# Metric
# Rating
# Remark
# Technical Specifications
# B
# Weatherproof gasket not as sturdy as competitor
# System Engineering
# A
# Light weight
# Craftsmanship
# A
#
# Summary:
# Channell OCFH FDH is the lightest among the FDH selection which is ideal for pole mount application.
# There could be durability concern for pad mount application due to its lighter metal skin. The
# weatherproofing gasket is not as tight of seal compare to other similar product in the market
#
# [IMAGE: Xplore® X logo design with a modern and sleek aesthetic. Xplore® X]
# [IMAGE: Summary: A numerical display showing the value "3.8" prominently. Text extracted: 3.8]
# [IMAGE: Summary: An open electrical enclosure featuring internal wiring, green connectors, and a structured layout, likely used for telecommunications or network equipment. Text extraction: None.]
#
# TABLE:
# |Metric|Rating|Remark|
# |---|---|---|
# |Technical Specifications|A||
# |System Engineering|A||
# |Craftsmanship|A||
#
# TABLE:
# |Metric|Rating|Remark|
# |---|---|---|
# |Technical Specifications|B|Weatherproof gasket not as sturdy as competitor|
# |System Engineering|A|Light weight|
#
# |Craftsmanship|A||
#
#
# ===PAGE BREAK===
#
#
# Overall Rating:
# Number 1: Standard Choice of POLE MOUNTED FDH
# Number 3: Acceptable Alternate Choice of PAD MOUNTED FDH
#
# 3.8.2. Corning LS Series FDH (288F)
# Overview
# The OptiTect® Local Convergence Cabinet, LS Series provides everything necessary to manage up to
# 288 fibers for an outside plant FTTx application. The OptiTect Local Convergence Cabinet, LS Series is
# an innovative solution that is the optimal balance between size, density and access. All cabinets share
# the same intuitive and efficient cable routing and splitter storage. The LS cabinet was developed with the
# field craft in mind. In this unique cabinet design, splitter parking and cable toning are simple, providing
# customers more flexibility and deployment options. The best-in-class fiber routing design allows for quick
# subscriber turn-up and error-free long-term maintenance as the cabinet is loaded to capacity. Cabinet
# offer “pass-through” capabilities for commercial services or other high-bandwidth applications, as well as
# multiple mounting options to accommodate exclusive below ground and aerial plant installations.
#
# **Figure 24: Corning FDH LS Series**
#
# Metric
# Rating
# Remark
# Technical Specifications
# A
# Heavy, not ideal for Pole Mounted applicaiton
# System Engineering
# A
# Excellent weatherproofing material and door seal
# Craftsmanship
# A
#
# Summary:
# The Corning FDH is heavy so it is not ideal of Pole-Mounted application. It has good seal at the door and
# the cabinet is sturdy built. Every connection is terminated in the front so technician does not need to go to
# the back for any patching.
#
# [IMAGE: Xplore logo in green and black featuring stylized 'X' and the word "Xplore®" alongside it. Xplore®]
# [IMAGE: **Summary:** Interior view of a telecommunications equipment cabinet featuring various components such as a feeder input field, splitter module, and splice chamber, along with labeled features including a lifting eye, parking area, and optional pass-through. **Text Extraction:** - "Pass-through" (optional) - "216B Latch with padlock provision" - "Parking" - "Lifting Eye" - "Feeder (Input Field)" - "Splitter Module" - "Splice Chamber (optional)"]
#
# TABLE:
# |Metric|Rating|Remark|
# |---|---|---|
# |Technical Specifications|A|Heavy, not ideal for Pole Mounted applicaiton|
# |System Engineering|A|Excellent weatherproofing material and door seal|
#
# |Craftsmanship|A||
#
#
# ===PAGE BREAK===
#
#
# Overall Rating:
# Number 2: Acceptable Alternate Choice of POLE MOUNTED FDH
# Number 1: Standard Choice of PAD MOUNTED FDH
#
# 3.8.3. Commscope Outdoor FDH 3000
# Overview
# The FDH 3000 is designed to meet and serve the distinct needs of diverse markets and customer
# segments. The unique design of the FDH 3000 provides for rapid connection between fiber optic cables
# and passive optical splitters in the outside plant segment of the network, facilitating fast service
# connection and reconfiguration, simplified network installations and improved installation efficiencies in
# the field
#
# **Figure 25: Commscope FDH 3000**
#
# **Figure 26: Commscope FDH 3000 By-Pass access**
#
# Metric
# Rating
# Remark
# Technical Specifications
# A
#
# System Engineering
# A
# Excellent weatherproofing material and door seal
# Craftsmanship
# B
#
# By-Pass fibre are in the back
#
# Summary:
# The Commscope FDH 3000 has similar built quality as Corning’s counterpart. However, the drawback is
# locatioin of By-Pass termination, which is in the back of FDH and requires back and forth moving of the
# cabinet shelf. Not as user-friendly as other models compared.
# Overall Rating:
# Number 3: Acceptable Alternate Choice of POLE MOUNTED FDH
# Number 2: Acceptable Alternate Choice of PAD MOUNTED FDH
#
# [IMAGE: Xplore® X logo featuring a stylized "X" in dark green with simple, modern typography. Xplore® X]
# [IMAGE: - Summary: Fiber optic distribution enclosure with multiple yellow fiber optic cables and connectors mounted inside a secured cabinet. - Text: - Caution: - [Label or text content in the enclosure\\] - [Additional instructions or specifications\\] - [Other labels or markings\\] - [Wiring specifics or model information\\]]
# [IMAGE: **Summary:** Detailed view of an electronic equipment cabinet, showcasing internal wiring, connectors, and components designed for telecommunications. **Extracted Text:** (Since there is no visible text in the image, nothing to extract.)]
#
# TABLE:
# |Metric|Rating|Remark|
# |---|---|---|
# |Technical Specifications|A||
# |System Engineering|A|Excellent weatherproofing material and door seal|
#
# |Craftsmanship|B|By&amp;#45;Pass fibre are in the back|
#
#
# ===PAGE BREAK===
#
#
# Outside Plant Fibre Optic Cable
# Xplore are open to purchase cables from a number of fibre optic cable manufacturers. The standard cables
# to be used as a first choice for the majority of Xplore fibre network application are
# -
# Dielectric & single-jacket fibre optic cable
# -
# Dielectric & double-jacket/double-armour for gopher / rodent infested area as the outer shield is
# sacrificial to the gnawing of the gopher
# -
# All dielectric cables or Poly / Single Jacket used in areas which prevent the use of a cable with a
# metallic shield such as areas of Power Influence
# Advantage of going with dielectric cable is due to lighter weight so it is easier to withstand wind storm
# impact in Maritime provinces. Single Jacket cable without metallic armor does not require permit and
# meet hydro regulation in some territory / municipality. (No Pole-Line-Analysis “PLA” is required in
# Maritime provinces at the time of writing)
# The specification would be Xplore fibre network standards and guidelines unless the type of cable is
# dictated by the utility or regulatory requirement.
# Manufacturers
# -
# Corning SMF-28e+
# -
# AFL – LE Series / LN Series (Rodent Resistant)
# -
# Commscope – D-LN Series
#
# Overall Rating:
# Corning cable would be the standard choice of outdoor fibre optic cable, especially for critical run/path. The
# other manufacturers produce quality fibre optic cables that are also widely deployed across Canada. The
# preference would go to evaluation metrics 4-6 (pricing, lead time and distribution).
#
# [IMAGE: Xplore logo with the brand name "Xplore" in a modern font. Xplore® X]
# [IMAGE: Summary: A numerical value shown prominently in a stylized font, possibly indicating a score or rating. Text: 3.9.]
#
#
# ===PAGE BREAK===
#
#
# 4. OSP Products Standardization Summary
#
# Category
# 1st Choice (Standard)
# 2nd Choice
# (Replacement)
# Selection Criteria
# Multiport
# Terminal (MPT)
# Corning Evolv
# Corning OptiSheath /
# Commscope HST
# Small footprint, quick & easy
# drop connection
# Drop Cable
# Corning Evolv ROC
# Commscope OptiTap
# Prefer round drop cable for
# various applications
# Mechanical
# Connector
# Corning NPC+
# AFL FASTConnect /
# Commscope QWIK-II
# Snug fit for signal lose
# prevention
# Fibre Optic
# Splice Closure
# (FOSC)
# Commscope 450
# Series
# Corning Fibre Dome
# Small footprint, easy to
# maintain & re-entry, excel in
# harsh environment
# Inline Terminal
# Corning SC8-9T
# N/A
#
# Fibre Patch
# Panel
# Wireworks’ NextSTEP
# N/A
# Easy fibre & connection
# access
# Transition
# Cabinet
# Multilink FEW-288
# N/A
# Small footprint
# FDH – Pole
# Mounted
# Channell Optimus
# Aerial Fibre Hub
# (OAFH)
# Corning LS Series
# Light weight and durable
# FDH – Pad
# Mounted
# Corning LS Series
# Commscope Outdoor
# FDH 3000
# Durable and good seal
# Outdoor Fibre
# Cable
# Corning
# AFL / Commscope
# Dielectric & Single Jacket.
# Avoid armoured cable if
# possible
#
# [IMAGE: Xplore logo featuring the name "Xplore" in a modern font with a stylized "X" motif. Xplore® X]
#
# TABLE:
# |Category|1st Choice (Standard)|2nd Choice (Replacement)|Selection Criteria|
# |---|---|---|---|
# |Multiport Terminal (MPT)|Corning Evolv|Corning OptiSheath / Commscope HST|Small footprint, quick &amp; easy drop connection|
# |Drop Cable|Corning Evolv ROC|Commscope OptiTap|Prefer round drop cable for various applications|
# |Mechanical Connector|Corning NPC+|AFL FASTConnect / Commscope QWIK-II|Snug fit for signal lose prevention|
# |Fibre Optic Splice Closure (FOSC)|Commscope 450 Series|Corning Fibre Dome|Small footprint, easy to maintain &amp; re-entry, excel in harsh environment|
# |Inline Terminal|Corning SC8-9T|N/A||
# |Fibre Patch Panel|Wireworks’ NextSTEP|N/A|Easy fibre &amp; connection access|
# |Transition Cabinet|Multilink FEW-288|N/A|Small footprint|
# |FDH – Pole Mounted|Channell Optimus Aerial Fibre Hub (OAFH)|Corning LS Series|Light weight and durable|
# |FDH – Pad Mounted|Corning LS Series|Commscope Outdoor FDH 3000|Durable and good seal|
#
# |Outdoor Fibre Cable|Corning|AFL / Commscope|Dielectric &amp; Single Jacket. Avoid armoured cable if possible|
#
#
# ===PAGE BREAK===
#
#
# 5. Document Information
#
#  Original Document Authors / Contributors
# Name
# Position
# Role
# Jacky Wong
# Senior Engineer
# Originator / Author
#
#  Document Approvers
# Name
# Position
# Date
# Status
# Seth Amankwah
#
# Director, Fibre
# Engineering
# 2023/Jan/23
# Approved & Released
#
#  Document Revision History
# Date of Revision
# Revised By
# Description
# Revision
# Page #
# Revised
# Section
# 2023/Dec/27
#
# Jacky Wong
#
# Replace Commscope MST with
# HST. Not Recommended Coyote
# FOSC
# 8,17
# 3.1.3, 3.4.4
# 2024/Jan/02
#
# Jacky Wong
#
# Typo correction
#
# [IMAGE: Xplore logo featuring the brand name in a modern font alongside a stylized "X". Xplore® X]
# [IMAGE: **Image Summary:** Section number 5.1. in a green font, possibly from a document or report. **Extracted Text:** 5.1.]
# [IMAGE: **Summary:** The image features the number "5.2" prominently displayed in a large, bold font. **Text extraction:** 5.2.]
# [IMAGE: 5.3.]
#
# TABLE:
# |Col1|Name|Col3|Col4|Position|Col6|Col7|Role|Col9|
# |---|---|---|---|---|---|---|---|---|
# |Jacky Wong|||Senior Engineer|||Originator / Author|||
# ||||||||||
#
# TABLE:
# |Col1|Name|Col3|Col4|Position|Col6|Col7|Date|Col9|Col10|Status|Col12|
# |---|---|---|---|---|---|---|---|---|---|---|---|
# |Seth Amankwah|||Director, Fibre Engineering|||2023/Jan/23|||Approved &amp; Released|||
#
# TABLE:
# |Date of Revision|Revised By|Description|Col4|Revision|Col6|Col7|Revised|Col9|
# |---|---|---|---|---|---|---|---|---|
# |||||Page #|||Section||
# |2023/Dec/27|Jacky Wong|Replace Commscope MST with HST. Not Recommended Coyote FOSC|8,17|||3.1.3, 3.4.4|||
# |2024/Jan/02|Jacky Wong|Typo correction|||||||
# ||||||||||
#
# ||||||||||
#
#
# ===PAGE BREAK===
